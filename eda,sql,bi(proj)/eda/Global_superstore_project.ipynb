# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\jyoth\Downloads\archive (22)\superstore.csv")

# %%
df.head(3)
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
#
#     Segment                Ship.Date       Ship.Mode  Shipping.Cost  \
# 0  Consumer  2011-01-09 00:00:00.000    Second Class           4.37
# 1  Consumer  2011-01-26 00:00:00.000  Standard Class           0.94
# 2  Consumer  2011-08-09 00:00:00.000  Standard Class           1.81
#
#         State  Sub.Category  Year        Market2 weeknum
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
# ...

# %%
df.shape
# Out:
# (51290, 27)

# %% [markdown]
# # cols to drop

# %% [markdown]
# 记录数
# Row.ID
# Customer.ID
# Order.ID
# Product.ID
# Market
# Market2
# Order.Priority
# Ship.Mode
# Ship.Date
# Shipping.Cost
# Year
# weeknum
# Discount   (optional – drop for now to keep it simple)

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# ...

# %%
df.drop('记录数', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
df.drop(['Row.ID','Customer.ID','Order.ID','Product.ID','Market','Market2','Order.Priority','Ship.Mode','Ship.Date','Shipping.Cost','Year','weeknum','Discount'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.Name', 'Order.Date',
#        'Product.Name', 'Profit', 'Quantity', 'Region', 'Sales', 'Segment',
#        'State', 'Sub.Category'],
#       dtype='object')

# %%
df.shape
# Out:
# (51290, 13)

# %% [markdown]
# # check for null values

# %%
df.isnull().sum() # no null values
# Out:
# Category         0
# City             0
# Country          0
# Customer.Name    0
# Order.Date       0
# Product.Name     0
# Profit           0
# Quantity         0
# Region           0
# Sales            0
# Segment          0
# State            0
# Sub.Category     0
# dtype: int64

# %% [markdown]
# # check for duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.replace('.', '_')
df.columns = df.columns.str.replace(' ', '_')
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['category', 'city', 'country', 'customer_name', 'order_date',
#        'product_name', 'profit', 'quantity', 'region', 'sales', 'segment',
#        'state', 'sub_category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51289
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       51281 non-null  object
#  1   city           51281 non-null  object
#  2   country        51281 non-null  object
#  3   customer_name  51281 non-null  object
#  4   order_date     51281 non-null  object
#  5   product_name   51281 non-null  object
#  6   profit         51281 non-null  float64
#  7   quantity       51281 non-null  int64
#  8   region         51281 non-null  object
#  9   sales          51281 non-null  int64
#  10  segment        51281 non-null  object
#  11  state          51281 non-null  object
#  12  sub_category   51281 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 5.5+ MB

# %%
df.head()
# Out:
#           category         city        country     customer_name  \
# 0  Office Supplies  Los Angeles  United States  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States      Chad Sievert
# 3  Office Supplies  Los Angeles  United States      Chad Sievert
# 4  Office Supplies  Los Angeles  United States    Arthur Prichep
#
#                 order_date                                       product_name  \
# 0  2011-01-07 00:00:00.000                                          Xerox 225
# 1  2011-01-21 00:00:00.000          Wirebound Service Call Books, 5 1/2" x 4"
# 2  2011-08-05 00:00:00.000  Adams Phone Message Book, Professional, 400 Me...
# 3  2011-08-05 00:00:00.000                                         Xerox 1913
# 4  2011-09-29 00:00:00.000                                          Xerox 223
#
#     profit  quantity region  sales   segment       state sub_category
# ...

# %%
# converting datatype

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['order_date'] = df['order_date'].dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51281 entries, 0 to 51289
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category       51281 non-null  object
#  1   city           51281 non-null  object
#  2   country        51281 non-null  object
#  3   customer_name  51281 non-null  object
#  4   order_date     51281 non-null  object
#  5   product_name   51281 non-null  object
#  6   profit         51281 non-null  float64
#  7   quantity       51281 non-null  int64
#  8   region         51281 non-null  object
#  9   sales          51281 non-null  int64
#  10  segment        51281 non-null  object
#  11  state          51281 non-null  object
#  12  sub_category   51281 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 5.5+ MB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df.to_csv("clean_superstore.csv", index=False)

# %%
pwd
# Out:
# 'C:\\Users\\jyoth'

# %%
df1 = pd.read_csv(r"C:\Users\jyoth\clean_superstore.csv")

# %%
df1
# Out:
#               category         city        country     customer_name  \
# 0      Office Supplies  Los Angeles  United States  Lycoris Saunders
# 1      Office Supplies  Los Angeles  United States     Mark Van Huff
# 2      Office Supplies  Los Angeles  United States      Chad Sievert
# 3      Office Supplies  Los Angeles  United States      Chad Sievert
# 4      Office Supplies  Los Angeles  United States    Arthur Prichep
# ...                ...          ...            ...               ...
# 51276  Office Supplies  Los Angeles  United States    Alice McCarthy
# 51277  Office Supplies  Los Angeles  United States    Alice McCarthy
# 51278  Office Supplies  Los Angeles  United States    Hallie Redmond
# 51279  Office Supplies  Los Angeles  United States     Robert Marley
# 51280  Office Supplies  Los Angeles  United States      Fred Hopkins
#
#        order_date                                       product_name   profit  \
# ...

# %%
import pandas as pd

df1 = pd.read_csv(r"C:\Users\jyoth\Downloads\clean_superstore3.csv", encoding="latin1")
df1.to_csv("final_clean_utf8.csv", index=False, encoding="utf-8")

# %%
pwd
# Out:
# 'C:\\Users\\jyoth'

# %%
df2 = pd.read_csv(r"C:\Users\jyoth\final_clean_utf8.csv")

# %%
df2.head(2)
# Out:
#        ï»¿category         city        country     customer_name  order_date  \
# 0  Office Supplies  Los Angeles  United States  Lycoris Saunders  07-01-2011
# 1  Office Supplies  Los Angeles  United States     Mark Van Huff  21-01-2011
#
#                                 product_name  profit  quantity region  sales  \
# 0                                  Xerox 225  9.3312         3   West     19
# 1  Wirebound Service Call Books, 5 1/2" x 4"  9.2928         2   West     19
#
#     segment       state sub_category
# 0  Consumer  California        Paper
# 1  Consumer  California        Paper
